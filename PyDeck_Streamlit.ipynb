# %% [markdown]
# # How to create a pydeck map

# %% [markdown]
# <img src="pydeck_logo.png" width="300"/>

# %% [markdown]
# Import the ```pydeck``` library and other useful ones.

# %%
import pydeck as pdk
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# Import dataset about [World Volcanos](https://hub.arcgis.com/datasets/2a45f767a6e549bfbe5bf638681f1fac/explore)

# %%
volcanos = gpd.read_file('https://services.arcgis.com/BG6nSlhZSAWtExvp/arcgis/rest/services/World_Volcanoes/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson')
volcanos['color'] = volcanos.ELEV.apply(lambda x: [(i * 255) for i in plt.cm.Blues((x-volcanos.ELEV.min()) / (volcanos.ELEV.max() - volcanos.ELEV.min()))[0:3]])
volcanos.head()
# Out:
#    OBJECTID                   NAME                 STATUS LATITUDE NS  \
# 0         1  West Eifel Volc Field            Radiocarbon    50.17  N
# 1         2        ChaŒne des Puys            Radiocarbon   45.775  N
# 2         3        Olot Volc Field              Holocene?    42.17  N
# 3         4             Larderello             Historical    43.25  N
# 4         5                 Amiata  Pleistocene-Fumarolic    42.90  N
#
#   LONGITUDE EW  ELEV               TYPE     Lat    Lon SimpleType  \
# 0      6.85  E   600               Maar  50.170   6.85    Caldera
# 1      2.97  E  1464        Cinder cone  45.775   2.97     Cinder
# 2      2.53  E   893   Pyroclastic cone  42.170   2.53     Cinder
# 3     10.87  E   500  Explosion craters  43.250  10.87    Caldera
# 4     11.63  E  1738          Lava dome  42.900  11.63  Composite
#
#                     geometry  \
# 0   POINT (6.85000 50.17000)
# 1   POINT (2.97000 45.77500)
# 2   POINT (2.53000 42.17000)
# 3  POINT (10.87000 43.25000)
# 4  POINT (11.63000 42.90000)
#
#                                                color
# 0  [88.34901960784313, 161.26274509803923, 206.72...
# 1  [65.3529411764706, 145.35294117647058, 197.666...
# 2  [80.63137254901966, 155.99215686274513, 203.70...
# 3  [92.2078431372549, 163.89803921568628, 208.227...
# 4  [59.14117647058824, 139.14117647058822, 194.46...

# %% [markdown]
# You can view ```GeoDataFrame``` geometries with ```explore()```

# %%
volcanos.explore()

# %% [markdown]
# Three components are required to create a ```pydeck``` map:
# - a view state (```pydeck.ViewState```)
# - one or more layers (```pydeck.Layer```)
# - a Deck object (```pydeck.Deck```)

# %% [markdown]
# The view state is used to define the mapping attributes, such as zoom, pitch, focus, bearing, etc.

# %%
view_state = pdk.ViewState(
                longitude=volcanos.Lon.mean(),
                latitude=volcanos.Lat.mean(),
                zoom=1,
                min_zoom=1,
                max_zoom=15
            )
view_state
# Out:
# {
#   "latitude": 20.985221999999997,
#   "longitude": 79.081306,
#   "maxZoom": 15,
#   "minZoom": 1,
#   "zoom": 1
# }

# %% [markdown]
# Create a ```ScatterplotLayer```

# %%
layer_pts = pdk.Layer(
    type="ScatterplotLayer",
    data=pd.DataFrame(volcanos.drop(columns='geometry')),
    get_fill_color='[color[0], color[1], color[2]]',
    get_radius=1,
    pickable=True,
    radius_scale=1,
    radius_min_pixels=5,
    radius_max_pixels=500,
    get_position='[Lon, Lat]'
    )

# %% [markdown]
# Create a ```pydeck.Deck``` object

# %%
pdk_map = pdk.Deck(
            map_provider='carto',
            map_style='light',
            initial_view_state=view_state,
            layers=[layer_pts]
            )
pdk_map
# Out:
# {
#   "initialViewState": {
#     "latitude": 20.985221999999997,
#     "longitude": 79.081306,
#     "maxZoom": 15,
#     "minZoom": 1,
#     "zoom": 1
#   },
#   "layers": [
#     {
#       "@@type": "ScatterplotLayer",
#       "data": [
#         {
#           "ELEV": 600,
#           "EW": "E",
#           "LATITUDE": "50.17",
#           "LONGITUDE": "6.85",
#           "Lat": 50.17,
#           "Lon": 6.85,
#           "NAME": "West Eifel Volc Field",
#           "NS": "N",
#           "OBJECTID": 1,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Caldera",
#           "TYPE": "Maar",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 1464,
#           "EW": "E",
#           "LATITUDE": "45.775",
#           "LONGITUDE": "2.97",
#           "Lat": 45.775,
#           "Lon": 2.97,
#           "NAME": "Cha\u0152ne des Puys",
#           "NS": "N",
#           "OBJECTID": 2,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             65.3529411764706,
#             145.35294117647058,
#             197.66666666666669
#           ]
#         },
#         {
#           "ELEV": 893,
#           "EW": "E",
#           "LATITUDE": "42.17",
#           "LONGITUDE": "2.53",
#           "Lat": 42.17,
#           "Lon": 2.53,
#           "NAME": "Olot Volc Field",
#           "NS": "N",
#           "OBJECTID": 3,
#           "STATUS": "Holocene?",
#           "SimpleType": "Cinder",
#           "TYPE": "Pyroclastic cone",
#           "color": [
#             80.63137254901966,
#             155.99215686274513,
#             203.70980392156864
#           ]
#         },
#         {
#           "ELEV": 500,
#           "EW": "E",
#           "LATITUDE": "43.25",
#           "LONGITUDE": "10.87",
#           "Lat": 43.25,
#           "Lon": 10.87,
#           "NAME": "Larderello",
#           "NS": "N",
#           "OBJECTID": 4,
#           "STATUS": "Historical",
#           "SimpleType": "Caldera",
#           "TYPE": "Explosion craters",
#           "color": [
#             92.2078431372549,
#             163.89803921568628,
#             208.22745098039215
#           ]
#         },
#         {
#           "ELEV": 1738,
#           "EW": "E",
#           "LATITUDE": "42.90",
#           "LONGITUDE": "11.63",
#           "Lat": 42.9,
#           "Lon": 11.63,
#           "NAME": "Amiata",
#           "NS": "N",
#           "OBJECTID": 5,
#           "STATUS": "Pleistocene-Fumarolic",
#           "SimpleType": "Composite",
#           "TYPE": "Lava dome",
#           "color": [
#             59.14117647058824,
#             139.14117647058822,
#             194.46666666666667
#           ]
#         },
#         {
#           "ELEV": 800,
#           "EW": "E",
#           "LATITUDE": "42.60",
#           "LONGITUDE": "11.93",
#           "Lat": 42.6,
#           "Lon": 11.93,
#           "NAME": "Vulsini",
#           "NS": "N",
#           "OBJECTID": 6,
#           "STATUS": "Historical",
#           "SimpleType": "Caldera",
#           "TYPE": "Caldera",
#           "color": [
#             83.20392156862745,
#             157.74901960784314,
#             204.71372549019608
#           ]
#         },
#         {
#           "ELEV": 949,
#           "EW": "E",
#           "LATITUDE": "41.73",
#           "LONGITUDE": "12.70",
#           "Lat": 41.73,
#           "Lon": 12.7,
#           "NAME": "Alban Hills",
#           "NS": "N",
#           "OBJECTID": 7,
#           "STATUS": "Holocene?",
#           "SimpleType": "Caldera",
#           "TYPE": "Caldera",
#           "color": [
#             79.3450980392157,
#             155.11372549019606,
#             203.2078431372549
#           ]
#         },
#         {
#           "ELEV": 458,
#           "EW": "E",
#           "LATITUDE": "40.827",
#           "LONGITUDE": "14.139",
#           "Lat": 40.827,
#           "Lon": 14.139,
#           "NAME": "Campi Flegrei",
#           "NS": "N",
#           "OBJECTID": 8,
#           "STATUS": "Historical",
#           "SimpleType": "Caldera",
#           "TYPE": "Caldera",
#           "color": [
#             93.49411764705883,
#             164.7764705882353,
#             208.72941176470587
#           ]
#         },
#         {
#           "ELEV": 1281,
#           "EW": "E",
#           "LATITUDE": "40.821",
#           "LONGITUDE": "14.426",
#           "Lat": 40.821,
#           "Lon": 14.426,
#           "NAME": "Vesuvius",
#           "NS": "N",
#           "OBJECTID": 9,
#           "STATUS": "Historical",
#           "SimpleType": "Caldera",
#           "TYPE": "Somma volcano",
#           "color": [
#             70.34117647058824,
#             148.96470588235294,
#             199.69411764705882
#           ]
#         },
#         {
#           "ELEV": 789,
#           "EW": "E",
#           "LATITUDE": "40.73",
#           "LONGITUDE": "13.897",
#           "Lat": 40.73,
#           "Lon": 13.897,
#           "NAME": "Ischia",
#           "NS": "N",
#           "OBJECTID": 10,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Complex volcano",
#           "color": [
#             83.20392156862745,
#             157.74901960784314,
#             204.71372549019608
#           ]
#         },
#         {
#           "ELEV": 421,
#           "EW": "E",
#           "LATITUDE": "38.63",
#           "LONGITUDE": "15.07",
#           "Lat": 38.63,
#           "Lon": 15.07,
#           "NAME": "Panarea",
#           "NS": "N",
#           "OBJECTID": 11,
#           "STATUS": "Pleistocene-Fumarolic",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             93.49411764705883,
#             164.7764705882353,
#             208.72941176470587
#           ]
#         },
#         {
#           "ELEV": 602,
#           "EW": "E",
#           "LATITUDE": "38.48",
#           "LONGITUDE": "14.95",
#           "Lat": 38.48,
#           "Lon": 14.95,
#           "NAME": "Lipari",
#           "NS": "N",
#           "OBJECTID": 12,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 924,
#           "EW": "E",
#           "LATITUDE": "38.789",
#           "LONGITUDE": "15.213",
#           "Lat": 38.789,
#           "Lon": 15.213,
#           "NAME": "Stromboli",
#           "NS": "N",
#           "OBJECTID": 13,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             79.3450980392157,
#             155.11372549019606,
#             203.2078431372549
#           ]
#         },
#         {
#           "ELEV": 500,
#           "EW": "E",
#           "LATITUDE": "38.404",
#           "LONGITUDE": "14.962",
#           "Lat": 38.404,
#           "Lon": 14.962,
#           "NAME": "Vulcano",
#           "NS": "N",
#           "OBJECTID": 14,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             92.2078431372549,
#             163.89803921568628,
#             208.22745098039215
#           ]
#         },
#         {
#           "ELEV": 3350,
#           "EW": "E",
#           "LATITUDE": "37.734",
#           "LONGITUDE": "15.004",
#           "Lat": 37.734,
#           "Lon": 15.004,
#           "NAME": "Etna",
#           "NS": "N",
#           "OBJECTID": 15,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             25.35294117647059,
#             103.21176470588235,
#             173.3529411764706
#           ]
#         },
#         {
#           "ELEV": 836,
#           "EW": "E",
#           "LATITUDE": "36.77",
#           "LONGITUDE": "12.02",
#           "Lat": 36.77,
#           "Lon": 12.02,
#           "NAME": "Pantelleria",
#           "NS": "N",
#           "OBJECTID": 16,
#           "STATUS": "Historical",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             81.91764705882353,
#             156.87058823529412,
#             204.21176470588233
#           ]
#         },
#         {
#           "ELEV": -8,
#           "EW": "E",
#           "LATITUDE": "37.10",
#           "LONGITUDE": "12.70",
#           "Lat": 37.1,
#           "Lon": 12.7,
#           "NAME": "Campi Flegrei Mar Sicilia",
#           "NS": "N",
#           "OBJECTID": 17,
#           "STATUS": "Historical",
#           "SimpleType": "Fissure",
#           "TYPE": "Submarine Volcano",
#           "color": [
#             106.35686274509804,
#             173.5607843137255,
#             213.74901960784314
#           ]
#         },
#         {
#           "ELEV": 760,
#           "EW": "E",
#           "LATITUDE": "37.615",
#           "LONGITUDE": "23.336",
#           "Lat": 37.615,
#           "Lon": 23.336,
#           "NAME": "Methana",
#           "NS": "N",
#           "OBJECTID": 18,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Lava dome",
#           "color": [
#             84.49019607843138,
#             158.62745098039215,
#             205.2156862745098
#           ]
#         },
#         {
#           "ELEV": 751,
#           "EW": "E",
#           "LATITUDE": "36.699",
#           "LONGITUDE": "24.439",
#           "Lat": 36.699,
#           "Lon": 24.439,
#           "NAME": "M\u00a1los",
#           "NS": "N",
#           "OBJECTID": 19,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             84.49019607843138,
#             158.62745098039215,
#             205.2156862745098
#           ]
#         },
#         {
#           "ELEV": 367,
#           "EW": "E",
#           "LATITUDE": "36.404",
#           "LONGITUDE": "25.396",
#           "Lat": 36.404,
#           "Lon": 25.396,
#           "NAME": "Santorini",
#           "NS": "N",
#           "OBJECTID": 20,
#           "STATUS": "Historical",
#           "SimpleType": "Shield",
#           "TYPE": "Sheild volcano",
#           "color": [
#             94.78039215686275,
#             165.65490196078431,
#             209.23137254901962
#           ]
#         },
#         {
#           "ELEV": 180,
#           "EW": "E",
#           "LATITUDE": "36.671",
#           "LONGITUDE": "27.140",
#           "Lat": 36.671,
#           "Lon": 27.14,
#           "NAME": "Yali",
#           "NS": "N",
#           "OBJECTID": 21,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Lava dome",
#           "color": [
#             99.92549019607844,
#             169.1686274509804,
#             211.23921568627452
#           ]
#         },
#         {
#           "ELEV": 698,
#           "EW": "E",
#           "LATITUDE": "36.586",
#           "LONGITUDE": "27.160",
#           "Lat": 36.586,
#           "Lon": 27.16,
#           "NAME": "Nisyros",
#           "NS": "N",
#           "OBJECTID": 22,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             85.7764705882353,
#             159.50588235294117,
#             205.71764705882353
#           ]
#         },
#         {
#           "ELEV": 430,
#           "EW": "E",
#           "LATITUDE": "36.852",
#           "LONGITUDE": "27.251",
#           "Lat": 36.852,
#           "Lon": 27.251,
#           "NAME": "Kos",
#           "NS": "N",
#           "OBJECTID": 23,
#           "STATUS": "Pleistocene-Fumarolic",
#           "SimpleType": "Caldera",
#           "TYPE": "Caldera",
#           "color": [
#             93.49411764705883,
#             164.7764705882353,
#             208.72941176470587
#           ]
#         },
#         {
#           "ELEV": 750,
#           "EW": "E",
#           "LATITUDE": "38.58",
#           "LONGITUDE": "28.52",
#           "Lat": 38.58,
#           "Lon": 28.52,
#           "NAME": "Kula",
#           "NS": "N",
#           "OBJECTID": 24,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             84.49019607843138,
#             158.62745098039215,
#             205.2156862745098
#           ]
#         },
#         {
#           "ELEV": 1302,
#           "EW": "E",
#           "LATITUDE": "37.67",
#           "LONGITUDE": "33.65",
#           "Lat": 37.67,
#           "Lon": 33.65,
#           "NAME": "Karapinar Field",
#           "NS": "N",
#           "OBJECTID": 25,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             69.0549019607843,
#             148.08627450980393,
#             199.1921568627451
#           ]
#         },
#         {
#           "ELEV": 3253,
#           "EW": "E",
#           "LATITUDE": "38.13",
#           "LONGITUDE": "34.17",
#           "Lat": 38.13,
#           "Lon": 34.17,
#           "NAME": "Hasan Dagi",
#           "NS": "N",
#           "OBJECTID": 26,
#           "STATUS": "Anthropology",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             26.92156862745098,
#             105.21960784313724,
#             174.921568627451
#           ]
#         },
#         {
#           "ELEV": 2143,
#           "EW": "E",
#           "LATITUDE": "38.25",
#           "LONGITUDE": "34.57",
#           "Lat": 38.25,
#           "Lon": 34.57,
#           "NAME": "G\u201dll\u0081 Dag",
#           "NS": "N",
#           "OBJECTID": 27,
#           "STATUS": "Holocene?",
#           "SimpleType": "Composite",
#           "TYPE": "Lava dome",
#           "color": [
#             49.82352941176471,
#             129.8235294117647,
#             189.66666666666669
#           ]
#         },
#         {
#           "ELEV": 1689,
#           "EW": "E",
#           "LATITUDE": "38.57",
#           "LONGITUDE": "34.52",
#           "Lat": 38.57,
#           "Lon": 34.52,
#           "NAME": "Acig\u201dl-Nevsehir",
#           "NS": "N",
#           "OBJECTID": 28,
#           "STATUS": "Anthropology",
#           "SimpleType": "Caldera",
#           "TYPE": "Caldera",
#           "color": [
#             60.1764705882353,
#             140.17647058823528,
#             195.00000000000003
#           ]
#         },
#         {
#           "ELEV": 1957,
#           "EW": "E",
#           "LATITUDE": "37.67",
#           "LONGITUDE": "39.83",
#           "Lat": 37.67,
#           "Lon": 39.83,
#           "NAME": "Karaca Dag",
#           "NS": "N",
#           "OBJECTID": 29,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             53.964705882352945,
#             133.96470588235294,
#             191.8
#           ]
#         },
#         {
#           "ELEV": 3916,
#           "EW": "E",
#           "LATITUDE": "38.52",
#           "LONGITUDE": "35.48",
#           "Lat": 38.52,
#           "Lon": 35.48,
#           "NAME": "Erciyes Dagi",
#           "NS": "N",
#           "OBJECTID": 30,
#           "STATUS": "Holocene?",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             15.941176470588237,
#             91.16470588235293,
#             163.94117647058826
#           ]
#         },
#         {
#           "ELEV": 4158,
#           "EW": "E",
#           "LATITUDE": "38.92",
#           "LONGITUDE": "42.82",
#           "Lat": 38.92,
#           "Lon": 42.82,
#           "NAME": "S\u0081phan Dagi",
#           "NS": "N",
#           "OBJECTID": 31,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             12.019607843137255,
#             86.14509803921568,
#             160.01960784313727
#           ]
#         },
#         {
#           "ELEV": 0,
#           "EW": "E",
#           "LATITUDE": "39.17",
#           "LONGITUDE": "43.33",
#           "Lat": 39.17,
#           "Lon": 43.33,
#           "NAME": "Girekol",
#           "NS": "N",
#           "OBJECTID": 32,
#           "STATUS": "Holocene",
#           "SimpleType": "Unknown",
#           "TYPE": "Unknown",
#           "color": [
#             105.07058823529412,
#             172.68235294117648,
#             213.24705882352941
#           ]
#         },
#         {
#           "ELEV": 2948,
#           "EW": "E",
#           "LATITUDE": "38.65",
#           "LONGITUDE": "42.23",
#           "Lat": 38.65,
#           "Lon": 42.23,
#           "NAME": "Nemrut Dagi",
#           "NS": "N",
#           "OBJECTID": 33,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             32.411764705882355,
#             112.24705882352941,
#             180.41176470588235
#           ]
#         },
#         {
#           "ELEV": 3584,
#           "EW": "E",
#           "LATITUDE": "39.37",
#           "LONGITUDE": "43.87",
#           "Lat": 39.37,
#           "Lon": 43.87,
#           "NAME": "Tend\u0081rek Dagi",
#           "NS": "N",
#           "OBJECTID": 34,
#           "STATUS": "Historical",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             21.431372549019606,
#             98.1921568627451,
#             169.4313725490196
#           ]
#         },
#         {
#           "ELEV": 5165,
#           "EW": "E",
#           "LATITUDE": "39.70",
#           "LONGITUDE": "44.30",
#           "Lat": 39.7,
#           "Lon": 44.3,
#           "NAME": "Ararat",
#           "NS": "N",
#           "OBJECTID": 35,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             8.0,
#             63.52941176470588,
#             130.05882352941177
#           ]
#         },
#         {
#           "ELEV": 3000,
#           "EW": "E",
#           "LATITUDE": "40.75",
#           "LONGITUDE": "42.90",
#           "Lat": 40.75,
#           "Lon": 42.9,
#           "NAME": "Kars Plateau",
#           "NS": "N",
#           "OBJECTID": 36,
#           "STATUS": "Holocene?",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             31.627450980392158,
#             111.24313725490195,
#             179.62745098039215
#           ]
#         },
#         {
#           "ELEV": 5633,
#           "EW": "E",
#           "LATITUDE": "43.33",
#           "LONGITUDE": "42.45",
#           "Lat": 43.33,
#           "Lon": 42.45,
#           "NAME": "Elbrus",
#           "NS": "N",
#           "OBJECTID": 37,
#           "STATUS": "Tephrochronology",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             8.0,
#             53.17647058823529,
#             114.68627450980392
#           ]
#         },
#         {
#           "ELEV": 5050,
#           "EW": "E",
#           "LATITUDE": "42.70",
#           "LONGITUDE": "44.50",
#           "Lat": 42.7,
#           "Lon": 44.5,
#           "NAME": "Kasbek",
#           "NS": "N",
#           "OBJECTID": 38,
#           "STATUS": "Tephrochronology",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             8.0,
#             66.63529411764705,
#             134.67058823529413
#           ]
#         },
#         {
#           "ELEV": 3650,
#           "EW": "E",
#           "LATITUDE": "42.55",
#           "LONGITUDE": "44.00",
#           "Lat": 42.55,
#           "Lon": 44.0,
#           "NAME": "Kabargin Oth Group",
#           "NS": "N",
#           "OBJECTID": 39,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             20.647058823529413,
#             97.18823529411763,
#             168.64705882352942
#           ]
#         },
#         {
#           "ELEV": 3750,
#           "EW": "E",
#           "LATITUDE": "42.45",
#           "LONGITUDE": "44.25",
#           "Lat": 42.45,
#           "Lon": 44.25,
#           "NAME": "Unnamed",
#           "NS": "N",
#           "OBJECTID": 40,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             19.07843137254902,
#             95.18039215686274,
#             167.078431372549
#           ]
#         },
#         {
#           "ELEV": 3400,
#           "EW": "E",
#           "LATITUDE": "41.55",
#           "LONGITUDE": "43.60",
#           "Lat": 41.55,
#           "Lon": 43.6,
#           "NAME": "Unnamed",
#           "NS": "N",
#           "OBJECTID": 41,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Lava cone",
#           "color": [
#             24.56862745098039,
#             102.2078431372549,
#             172.5686274509804
#           ]
#         },
#         {
#           "ELEV": 4095,
#           "EW": "E",
#           "LATITUDE": "40.53",
#           "LONGITUDE": "44.20",
#           "Lat": 40.53,
#           "Lon": 44.2,
#           "NAME": "Aragats",
#           "NS": "N",
#           "OBJECTID": 42,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             12.803921568627452,
#             87.14901960784313,
#             160.80392156862746
#           ]
#         },
#         {
#           "ELEV": 3597,
#           "EW": "E",
#           "LATITUDE": "40.275",
#           "LONGITUDE": "44.75",
#           "Lat": 40.275,
#           "Lon": 44.75,
#           "NAME": "Ghegam Ridge",
#           "NS": "N",
#           "OBJECTID": 43,
#           "STATUS": "Anthropology",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             21.431372549019606,
#             98.1921568627451,
#             169.4313725490196
#           ]
#         },
#         {
#           "ELEV": 3329,
#           "EW": "E",
#           "LATITUDE": "39.70",
#           "LONGITUDE": "45.542",
#           "Lat": 39.7,
#           "Lon": 45.542,
#           "NAME": "Dar-Alages",
#           "NS": "N",
#           "OBJECTID": 44,
#           "STATUS": "Anthropology",
#           "SimpleType": "Cinder",
#           "TYPE": "Pyroclastic cone",
#           "color": [
#             26.137254901960787,
#             104.2156862745098,
#             174.13725490196077
#           ]
#         },
#         {
#           "ELEV": 2800,
#           "EW": "E",
#           "LATITUDE": "40.02",
#           "LONGITUDE": "45.78",
#           "Lat": 40.02,
#           "Lon": 45.78,
#           "NAME": "Porak",
#           "NS": "N",
#           "OBJECTID": 45,
#           "STATUS": "Anthropology",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             35.32941176470588,
#             115.32941176470588,
#             182.20000000000002
#           ]
#         },
#         {
#           "ELEV": 3000,
#           "EW": "E",
#           "LATITUDE": "39.73",
#           "LONGITUDE": "46.02",
#           "Lat": 39.73,
#           "Lon": 46.02,
#           "NAME": "Tskhouk-Karckar",
#           "NS": "N",
#           "OBJECTID": 46,
#           "STATUS": "Tephrochronology",
#           "SimpleType": "Cinder",
#           "TYPE": "Pyroclastic cone",
#           "color": [
#             31.627450980392158,
#             111.24313725490195,
#             179.62745098039215
#           ]
#         },
#         {
#           "ELEV": 244,
#           "EW": "E",
#           "LATITUDE": "15.55",
#           "LONGITUDE": "41.82",
#           "Lat": 15.55,
#           "Lon": 41.82,
#           "NAME": "Tair, Jebel at",
#           "NS": "N",
#           "OBJECTID": 47,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             98.63921568627451,
#             168.29019607843136,
#             210.7372549019608
#           ]
#         },
#         {
#           "ELEV": 624,
#           "EW": "E",
#           "LATITUDE": "14.02",
#           "LONGITUDE": "42.75",
#           "Lat": 14.02,
#           "Lon": 42.75,
#           "NAME": "Zukur",
#           "NS": "N",
#           "OBJECTID": 48,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 422,
#           "EW": "E",
#           "LATITUDE": "13.72",
#           "LONGITUDE": "42.73",
#           "Lat": 13.72,
#           "Lon": 42.73,
#           "NAME": "Hanish",
#           "NS": "N",
#           "OBJECTID": 49,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             93.49411764705883,
#             164.7764705882353,
#             208.72941176470587
#           ]
#         },
#         {
#           "ELEV": 191,
#           "EW": "E",
#           "LATITUDE": "15.05",
#           "LONGITUDE": "42.18",
#           "Lat": 15.05,
#           "Lon": 42.18,
#           "NAME": "Zubair, Jebel",
#           "NS": "N",
#           "OBJECTID": 50,
#           "STATUS": "Historical",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             99.92549019607844,
#             169.1686274509804,
#             211.23921568627452
#           ]
#         },
#         {
#           "ELEV": 713,
#           "EW": "E",
#           "LATITUDE": "15.042",
#           "LONGITUDE": "39.82",
#           "Lat": 15.042,
#           "Lon": 39.82,
#           "NAME": "Jalua",
#           "NS": "N",
#           "OBJECTID": 51,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             85.7764705882353,
#             159.50588235294117,
#             205.71764705882353
#           ]
#         },
#         {
#           "ELEV": -48,
#           "EW": "E",
#           "LATITUDE": "14.242",
#           "LONGITUDE": "40.30",
#           "Lat": 14.242,
#           "Lon": 40.3,
#           "NAME": "Dallol",
#           "NS": "N",
#           "OBJECTID": 52,
#           "STATUS": "Historical",
#           "SimpleType": "Caldera",
#           "TYPE": "Explosion craters",
#           "color": [
#             106.35686274509804,
#             173.5607843137255,
#             213.74901960784314
#           ]
#         },
#         {
#           "ELEV": 904,
#           "EW": "E",
#           "LATITUDE": "14.88",
#           "LONGITUDE": "39.92",
#           "Lat": 14.88,
#           "Lon": 39.92,
#           "NAME": "Alid",
#           "NS": "N",
#           "OBJECTID": 53,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             80.63137254901966,
#             155.99215686274513,
#             203.70980392156864
#           ]
#         },
#         {
#           "ELEV": 287,
#           "EW": "E",
#           "LATITUDE": "13.975",
#           "LONGITUDE": "40.408",
#           "Lat": 13.975,
#           "Lon": 40.408,
#           "NAME": "Gada Ale",
#           "NS": "N",
#           "OBJECTID": 54,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             97.3529411764706,
#             167.41176470588235,
#             210.23529411764707
#           ]
#         },
#         {
#           "ELEV": 429,
#           "EW": "E",
#           "LATITUDE": "13.82",
#           "LONGITUDE": "40.55",
#           "Lat": 13.82,
#           "Lon": 40.55,
#           "NAME": "Alu",
#           "NS": "N",
#           "OBJECTID": 55,
#           "STATUS": "Holocene",
#           "SimpleType": "Fissure",
#           "TYPE": "Fissure vents",
#           "color": [
#             93.49411764705883,
#             164.7764705882353,
#             208.72941176470587
#           ]
#         },
#         {
#           "ELEV": 668,
#           "EW": "E",
#           "LATITUDE": "13.725",
#           "LONGITUDE": "40.60",
#           "Lat": 13.725,
#           "Lon": 40.6,
#           "NAME": "Borale Ale",
#           "NS": "N",
#           "OBJECTID": 56,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             87.06274509803922,
#             160.3843137254902,
#             206.21960784313725
#           ]
#         },
#         {
#           "ELEV": 613,
#           "EW": "E",
#           "LATITUDE": "13.792",
#           "LONGITUDE": "40.55",
#           "Lat": 13.792,
#           "Lon": 40.55,
#           "NAME": "Dalaffilla",
#           "NS": "N",
#           "OBJECTID": 57,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 613,
#           "EW": "E",
#           "LATITUDE": "13.60",
#           "LONGITUDE": "40.67",
#           "Lat": 13.6,
#           "Lon": 40.67,
#           "NAME": "Erta Ale",
#           "NS": "N",
#           "OBJECTID": 58,
#           "STATUS": "Historical",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 521,
#           "EW": "E",
#           "LATITUDE": "13.50",
#           "LONGITUDE": "40.72",
#           "Lat": 13.5,
#           "Lon": 40.72,
#           "NAME": "Hayli Gubbi",
#           "NS": "N",
#           "OBJECTID": 59,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             90.92156862745098,
#             163.01960784313724,
#             207.72549019607845
#           ]
#         },
#         {
#           "ELEV": 1031,
#           "EW": "E",
#           "LATITUDE": "13.52",
#           "LONGITUDE": "40.63",
#           "Lat": 13.52,
#           "Lon": 40.63,
#           "NAME": "Ale Bagu",
#           "NS": "N",
#           "OBJECTID": 60,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             76.77254901960785,
#             153.35686274509806,
#             202.20392156862746
#           ]
#         },
#         {
#           "ELEV": 2218,
#           "EW": "E",
#           "LATITUDE": "13.37",
#           "LONGITUDE": "41.70",
#           "Lat": 13.37,
#           "Lon": 41.7,
#           "NAME": "Nabro",
#           "NS": "N",
#           "OBJECTID": 61,
#           "STATUS": "Holocene?",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             48.78823529411765,
#             128.78823529411764,
#             189.13333333333335
#           ]
#         },
#         {
#           "ELEV": 1875,
#           "EW": "E",
#           "LATITUDE": "13.27",
#           "LONGITUDE": "41.65",
#           "Lat": 13.27,
#           "Lon": 41.65,
#           "NAME": "Mallahle",
#           "NS": "N",
#           "OBJECTID": 62,
#           "STATUS": "Holocene?",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             56.03529411764706,
#             136.03529411764706,
#             192.86666666666667
#           ]
#         },
#         {
#           "ELEV": 1611,
#           "EW": "E",
#           "LATITUDE": "13.18",
#           "LONGITUDE": "41.725",
#           "Lat": 13.18,
#           "Lon": 41.725,
#           "NAME": "Sork Ale",
#           "NS": "N",
#           "OBJECTID": 63,
#           "STATUS": "Holocene?",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             62.24705882352942,
#             142.24705882352941,
#             196.0666666666667
#           ]
#         },
#         {
#           "ELEV": 1200,
#           "EW": "E",
#           "LATITUDE": "13.07",
#           "LONGITUDE": "41.60",
#           "Lat": 13.07,
#           "Lon": 41.6,
#           "NAME": "Asavyo",
#           "NS": "N",
#           "OBJECTID": 64,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             72.91372549019609,
#             150.72156862745098,
#             200.69803921568626
#           ]
#         },
#         {
#           "ELEV": 523,
#           "EW": "E",
#           "LATITUDE": "13.10",
#           "LONGITUDE": "41.15",
#           "Lat": 13.1,
#           "Lon": 41.15,
#           "NAME": "Mat Ala",
#           "NS": "N",
#           "OBJECTID": 65,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             90.92156862745098,
#             163.01960784313724,
#             207.72549019607845
#           ]
#         },
#         {
#           "ELEV": 700,
#           "EW": "E",
#           "LATITUDE": "13.28",
#           "LONGITUDE": "41.07",
#           "Lat": 13.28,
#           "Lon": 41.07,
#           "NAME": "Tat Ali",
#           "NS": "N",
#           "OBJECTID": 66,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             85.7764705882353,
#             159.50588235294117,
#             205.71764705882353
#           ]
#         },
#         {
#           "ELEV": 812,
#           "EW": "E",
#           "LATITUDE": "13.30",
#           "LONGITUDE": "40.98",
#           "Lat": 13.3,
#           "Lon": 40.98,
#           "NAME": "Borawli",
#           "NS": "N",
#           "OBJECTID": 67,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             83.20392156862745,
#             157.74901960784314,
#             204.71372549019608
#           ]
#         },
#         {
#           "ELEV": 1625,
#           "EW": "E",
#           "LATITUDE": "13.58",
#           "LONGITUDE": "41.808",
#           "Lat": 13.58,
#           "Lon": 41.808,
#           "NAME": "Dubbi",
#           "NS": "N",
#           "OBJECTID": 68,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             61.21176470588239,
#             141.21176470588236,
#             195.53333333333336
#           ]
#         },
#         {
#           "ELEV": 1815,
#           "EW": "E",
#           "LATITUDE": "13.02",
#           "LONGITUDE": "40.20",
#           "Lat": 13.02,
#           "Lon": 40.2,
#           "NAME": "Ma Alalta",
#           "NS": "N",
#           "OBJECTID": 69,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             57.070588235294125,
#             137.0705882352941,
#             193.4
#           ]
#         },
#         {
#           "ELEV": 1501,
#           "EW": "E",
#           "LATITUDE": "12.88",
#           "LONGITUDE": "40.57",
#           "Lat": 12.88,
#           "Lon": 40.57,
#           "NAME": "Alayta",
#           "NS": "N",
#           "OBJECTID": 70,
#           "STATUS": "Historical",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             64.31764705882354,
#             144.31764705882352,
#             197.13333333333333
#           ]
#         },
#         {
#           "ELEV": 1442,
#           "EW": "E",
#           "LATITUDE": "12.60",
#           "LONGITUDE": "40.48",
#           "Lat": 12.6,
#           "Lon": 40.48,
#           "NAME": "Dabbahu",
#           "NS": "N",
#           "OBJECTID": 71,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             65.3529411764706,
#             145.35294117647058,
#             197.66666666666669
#           ]
#         },
#         {
#           "ELEV": 1302,
#           "EW": "E",
#           "LATITUDE": "12.38",
#           "LONGITUDE": "40.07",
#           "Lat": 12.38,
#           "Lon": 40.07,
#           "NAME": "Dabbayra",
#           "NS": "N",
#           "OBJECTID": 72,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             69.0549019607843,
#             148.08627450980393,
#             199.1921568627451
#           ]
#         },
#         {
#           "ELEV": 600,
#           "EW": "E",
#           "LATITUDE": "12.17",
#           "LONGITUDE": "40.82",
#           "Lat": 12.17,
#           "Lon": 40.82,
#           "NAME": "Manda Hararo",
#           "NS": "N",
#           "OBJECTID": 73,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Sheild volcano",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 930,
#           "EW": "E",
#           "LATITUDE": "11.73",
#           "LONGITUDE": "40.25",
#           "Lat": 11.73,
#           "Lon": 40.25,
#           "NAME": "Groppo",
#           "NS": "N",
#           "OBJECTID": 74,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             79.3450980392157,
#             155.11372549019606,
#             203.2078431372549
#           ]
#         },
#         {
#           "ELEV": 1295,
#           "EW": "E",
#           "LATITUDE": "13.08",
#           "LONGITUDE": "40.85",
#           "Lat": 13.08,
#           "Lon": 40.85,
#           "NAME": "Afder\u2026",
#           "NS": "N",
#           "OBJECTID": 75,
#           "STATUS": "Holocene?",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             69.0549019607843,
#             148.08627450980393,
#             199.1921568627451
#           ]
#         },
#         {
#           "ELEV": 875,
#           "EW": "E",
#           "LATITUDE": "11.63",
#           "LONGITUDE": "41.45",
#           "Lat": 11.63,
#           "Lon": 41.45,
#           "NAME": "Borawli",
#           "NS": "N",
#           "OBJECTID": 76,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Lava dome",
#           "color": [
#             81.91764705882353,
#             156.87058823529412,
#             204.21176470588233
#           ]
#         },
#         {
#           "ELEV": 600,
#           "EW": "E",
#           "LATITUDE": "12.38",
#           "LONGITUDE": "42.20",
#           "Lat": 12.38,
#           "Lon": 42.2,
#           "NAME": "Manda-Inakir",
#           "NS": "N",
#           "OBJECTID": 77,
#           "STATUS": "Historical",
#           "SimpleType": "Fissure",
#           "TYPE": "Fissure vents",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 2028,
#           "EW": "E",
#           "LATITUDE": "12.47",
#           "LONGITUDE": "42.40",
#           "Lat": 12.47,
#           "Lon": 42.4,
#           "NAME": "Mousa Alli",
#           "NS": "N",
#           "OBJECTID": 78,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             52.92941176470589,
#             132.9294117647059,
#             191.26666666666665
#           ]
#         },
#         {
#           "ELEV": 600,
#           "EW": "E",
#           "LATITUDE": "12.55",
#           "LONGITUDE": "42.53",
#           "Lat": 12.55,
#           "Lon": 42.53,
#           "NAME": "Gufa",
#           "NS": "N",
#           "OBJECTID": 79,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 987,
#           "EW": "E",
#           "LATITUDE": "12.95",
#           "LONGITUDE": "42.43",
#           "Lat": 12.95,
#           "Lon": 42.43,
#           "NAME": "Assab Volc Field",
#           "NS": "N",
#           "OBJECTID": 80,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             78.05882352941177,
#             154.23529411764704,
#             202.7058823529412
#           ]
#         },
#         {
#           "ELEV": 298,
#           "EW": "E",
#           "LATITUDE": "11.58",
#           "LONGITUDE": "42.47",
#           "Lat": 11.58,
#           "Lon": 42.47,
#           "NAME": "Ardouk\u201cba",
#           "NS": "N",
#           "OBJECTID": 81,
#           "STATUS": "Historical",
#           "SimpleType": "Fissure",
#           "TYPE": "Fissure vents",
#           "color": [
#             97.3529411764706,
#             167.41176470588235,
#             210.23529411764707
#           ]
#         },
#         {
#           "ELEV": 625,
#           "EW": "E",
#           "LATITUDE": "11.88",
#           "LONGITUDE": "41.208",
#           "Lat": 11.88,
#           "Lon": 41.208,
#           "NAME": "Kurub",
#           "NS": "N",
#           "OBJECTID": 82,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 1000,
#           "EW": "E",
#           "LATITUDE": "11.42",
#           "LONGITUDE": "42.20",
#           "Lat": 11.42,
#           "Lon": 42.2,
#           "NAME": "Garbes",
#           "NS": "N",
#           "OBJECTID": 83,
#           "STATUS": "Pleistocene-Fumarolic",
#           "SimpleType": "Composite",
#           "TYPE": "Fumarole field",
#           "color": [
#             78.05882352941177,
#             154.23529411764704,
#             202.7058823529412
#           ]
#         },
#         {
#           "ELEV": 1068,
#           "EW": "E",
#           "LATITUDE": "11.28",
#           "LONGITUDE": "41.63",
#           "Lat": 11.28,
#           "Lon": 41.63,
#           "NAME": "Dama Ali",
#           "NS": "N",
#           "OBJECTID": 84,
#           "STATUS": "Historical",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             75.48627450980392,
#             152.478431372549,
#             201.7019607843137
#           ]
#         },
#         {
#           "ELEV": 300,
#           "EW": "E",
#           "LATITUDE": "11.25",
#           "LONGITUDE": "41.83",
#           "Lat": 11.25,
#           "Lon": 41.83,
#           "NAME": "Boina",
#           "NS": "N",
#           "OBJECTID": 85,
#           "STATUS": "Pleistocene-Fumarolic",
#           "SimpleType": "Composite",
#           "TYPE": "Fumarole field",
#           "color": [
#             97.3529411764706,
#             167.41176470588235,
#             210.23529411764707
#           ]
#         },
#         {
#           "ELEV": 1383,
#           "EW": "E",
#           "LATITUDE": "10.58",
#           "LONGITUDE": "41.042",
#           "Lat": 10.58,
#           "Lon": 41.042,
#           "NAME": "Yangudi",
#           "NS": "N",
#           "OBJECTID": 86,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Complex volcano",
#           "color": [
#             67.76862745098039,
#             147.20784313725488,
#             198.6901960784314
#           ]
#         },
#         {
#           "ELEV": 1459,
#           "EW": "E",
#           "LATITUDE": "11.08",
#           "LONGITUDE": "41.27",
#           "Lat": 11.08,
#           "Lon": 41.27,
#           "NAME": "Gabillema",
#           "NS": "N",
#           "OBJECTID": 87,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             65.3529411764706,
#             145.35294117647058,
#             197.66666666666669
#           ]
#         },
#         {
#           "ELEV": 2145,
#           "EW": "E",
#           "LATITUDE": "10.082",
#           "LONGITUDE": "40.702",
#           "Lat": 10.082,
#           "Lon": 40.702,
#           "NAME": "Ayelu",
#           "NS": "N",
#           "OBJECTID": 88,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             49.82352941176471,
#             129.8235294117647,
#             189.66666666666669
#           ]
#         },
#         {
#           "ELEV": 900,
#           "EW": "E",
#           "LATITUDE": "9.78",
#           "LONGITUDE": "40.33",
#           "Lat": 9.78,
#           "Lon": 40.33,
#           "NAME": "Hertali",
#           "NS": "N",
#           "OBJECTID": 89,
#           "STATUS": "Holocene",
#           "SimpleType": "Fissure",
#           "TYPE": "Fissure vents",
#           "color": [
#             80.63137254901966,
#             155.99215686274513,
#             203.70980392156864
#           ]
#         },
#         {
#           "ELEV": 878,
#           "EW": "E",
#           "LATITUDE": "9.57",
#           "LONGITUDE": "40.28",
#           "Lat": 9.57,
#           "Lon": 40.28,
#           "NAME": "Liado Hayk",
#           "NS": "N",
#           "OBJECTID": 90,
#           "STATUS": "Holocene?",
#           "SimpleType": "Caldera",
#           "TYPE": "Maar",
#           "color": [
#             80.63137254901966,
#             155.99215686274513,
#             203.70980392156864
#           ]
#         },
#         {
#           "ELEV": 1733,
#           "EW": "E",
#           "LATITUDE": "10.070",
#           "LONGITUDE": "40.840",
#           "Lat": 10.07,
#           "Lon": 40.84,
#           "NAME": "Adwa",
#           "NS": "N",
#           "OBJECTID": 91,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             59.14117647058824,
#             139.14117647058822,
#             194.46666666666667
#           ]
#         },
#         {
#           "ELEV": 1151,
#           "EW": "E",
#           "LATITUDE": "9.35",
#           "LONGITUDE": "40.13",
#           "Lat": 9.35,
#           "Lon": 40.13,
#           "NAME": "Dofen",
#           "NS": "N",
#           "OBJECTID": 92,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             74.2,
#             151.6,
#             201.20000000000002
#           ]
#         },
#         {
#           "ELEV": 1100,
#           "EW": "E",
#           "LATITUDE": "8.95",
#           "LONGITUDE": "39.75",
#           "Lat": 8.95,
#           "Lon": 39.75,
#           "NAME": "Beru",
#           "NS": "N",
#           "OBJECTID": 93,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             75.48627450980392,
#             152.478431372549,
#             201.7019607843137
#           ]
#         },
#         {
#           "ELEV": 2007,
#           "EW": "E",
#           "LATITUDE": "8.975",
#           "LONGITUDE": "39.93",
#           "Lat": 8.975,
#           "Lon": 39.93,
#           "NAME": "Fentale",
#           "NS": "N",
#           "OBJECTID": 94,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             52.92941176470589,
#             132.9294117647059,
#             191.26666666666665
#           ]
#         },
#         {
#           "ELEV": 1619,
#           "EW": "E",
#           "LATITUDE": "8.80",
#           "LONGITUDE": "39.692",
#           "Lat": 8.8,
#           "Lon": 39.692,
#           "NAME": "Kone",
#           "NS": "N",
#           "OBJECTID": 95,
#           "STATUS": "Historical",
#           "SimpleType": "Caldera",
#           "TYPE": "Caldera",
#           "color": [
#             62.24705882352942,
#             142.24705882352941,
#             196.0666666666667
#           ]
#         },
#         {
#           "ELEV": 1300,
#           "EW": "E",
#           "LATITUDE": "8.70",
#           "LONGITUDE": "39.63",
#           "Lat": 8.7,
#           "Lon": 39.63,
#           "NAME": "Unnamed",
#           "NS": "N",
#           "OBJECTID": 96,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Pyroclastic cone",
#           "color": [
#             69.0549019607843,
#             148.08627450980393,
#             199.1921568627451
#           ]
#         },
#         {
#           "ELEV": 2447,
#           "EW": "E",
#           "LATITUDE": "8.558",
#           "LONGITUDE": "39.475",
#           "Lat": 8.558,
#           "Lon": 39.475,
#           "NAME": "Boset-Bericha",
#           "NS": "N",
#           "OBJECTID": 97,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             43.61176470588236,
#             123.61176470588235,
#             186.46666666666667
#           ]
#         },
#         {
#           "ELEV": 1850,
#           "EW": "E",
#           "LATITUDE": "8.78",
#           "LONGITUDE": "38.98",
#           "Lat": 8.78,
#           "Lon": 38.98,
#           "NAME": "Bishoftu Volc Field",
#           "NS": "N",
#           "OBJECTID": 98,
#           "STATUS": "Holocene",
#           "SimpleType": "Fissure",
#           "TYPE": "Fissure vents",
#           "color": [
#             57.070588235294125,
#             137.0705882352941,
#             193.4
#           ]
#         },
#         {
#           "ELEV": 1800,
#           "EW": "E",
#           "LATITUDE": "8.62",
#           "LONGITUDE": "38.95",
#           "Lat": 8.62,
#           "Lon": 38.95,
#           "NAME": "Unnamed",
#           "NS": "N",
#           "OBJECTID": 99,
#           "STATUS": "Holocene",
#           "SimpleType": "Fissure",
#           "TYPE": "Fissure vents",
# ...
#           "NAME": "Denison",
#           "NS": "N",
#           "OBJECTID": 969,
#           "STATUS": "Uncertain",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             46.71764705882353,
#             126.71764705882353,
#             188.0666666666667
#           ]
#         },
#         {
#           "ELEV": 2272,
#           "EW": "W",
#           "LATITUDE": "58.43",
#           "LONGITUDE": "154.40",
#           "Lat": 58.43,
#           "Lon": -154.4,
#           "NAME": "Steller",
#           "NS": "N",
#           "OBJECTID": 970,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             46.71764705882353,
#             126.71764705882353,
#             188.0666666666667
#           ]
#         },
#         {
#           "ELEV": 2043,
#           "EW": "W",
#           "LATITUDE": "58.453",
#           "LONGITUDE": "154.355",
#           "Lat": 58.453,
#           "Lon": -154.355,
#           "NAME": "Kukak",
#           "NS": "N",
#           "OBJECTID": 971,
#           "STATUS": "Fumarolic",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             51.894117647058835,
#             131.8941176470588,
#             190.73333333333335
#           ]
#         },
#         {
#           "ELEV": 901,
#           "EW": "W",
#           "LATITUDE": "58.608",
#           "LONGITUDE": "154.028",
#           "Lat": 58.608,
#           "Lon": -154.028,
#           "NAME": "Kaguyak",
#           "NS": "N",
#           "OBJECTID": 972,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             80.63137254901966,
#             155.99215686274513,
#             203.70980392156864
#           ]
#         },
#         {
#           "ELEV": 2105,
#           "EW": "W",
#           "LATITUDE": "58.770",
#           "LONGITUDE": "153.672",
#           "Lat": 58.77,
#           "Lon": -153.672,
#           "NAME": "Fourpeaked",
#           "NS": "N",
#           "OBJECTID": 973,
#           "STATUS": "Holocene?",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             50.85882352941177,
#             130.85882352941175,
#             190.2
#           ]
#         },
#         {
#           "ELEV": 2140,
#           "EW": "W",
#           "LATITUDE": "58.855",
#           "LONGITUDE": "153.542",
#           "Lat": 58.855,
#           "Lon": -153.542,
#           "NAME": "Douglas",
#           "NS": "N",
#           "OBJECTID": 974,
#           "STATUS": "Holocene",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             49.82352941176471,
#             129.8235294117647,
#             189.66666666666669
#           ]
#         },
#         {
#           "ELEV": 1252,
#           "EW": "W",
#           "LATITUDE": "59.363",
#           "LONGITUDE": "153.43",
#           "Lat": 59.363,
#           "Lon": -153.43,
#           "NAME": "Augustine",
#           "NS": "N",
#           "OBJECTID": 975,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Lava dome",
#           "color": [
#             70.34117647058824,
#             148.96470588235294,
#             199.69411764705882
#           ]
#         },
#         {
#           "ELEV": 3053,
#           "EW": "W",
#           "LATITUDE": "60.032",
#           "LONGITUDE": "153.090",
#           "Lat": 60.032,
#           "Lon": -153.09,
#           "NAME": "Iliamna",
#           "NS": "N",
#           "OBJECTID": 976,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             30.843137254901965,
#             110.2392156862745,
#             178.843137254902
#           ]
#         },
#         {
#           "ELEV": 3108,
#           "EW": "W",
#           "LATITUDE": "60.485",
#           "LONGITUDE": "152.742",
#           "Lat": 60.485,
#           "Lon": -152.742,
#           "NAME": "Redoubt",
#           "NS": "N",
#           "OBJECTID": 977,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             29.274509803921593,
#             108.23137254901964,
#             177.2745098039216
#           ]
#         },
#         {
#           "ELEV": 3374,
#           "EW": "W",
#           "LATITUDE": "61.299",
#           "LONGITUDE": "152.251",
#           "Lat": 61.299,
#           "Lon": -152.251,
#           "NAME": "Spurr",
#           "NS": "N",
#           "OBJECTID": 978,
#           "STATUS": "Historical",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             25.35294117647059,
#             103.21176470588235,
#             173.3529411764706
#           ]
#         },
#         {
#           "ELEV": 3034,
#           "EW": "W",
#           "LATITUDE": "61.640",
#           "LONGITUDE": "152.411",
#           "Lat": 61.64,
#           "Lon": -152.411,
#           "NAME": "Hayes",
#           "NS": "N",
#           "OBJECTID": 979,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             30.843137254901965,
#             110.2392156862745,
#             178.843137254902
#           ]
#         },
#         {
#           "ELEV": 203,
#           "EW": "W",
#           "LATITUDE": "57.18",
#           "LONGITUDE": "170.30",
#           "Lat": 57.18,
#           "Lon": -170.3,
#           "NAME": "St. Paul Island",
#           "NS": "N",
#           "OBJECTID": 980,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             99.92549019607844,
#             169.1686274509804,
#             211.23921568627452
#           ]
#         },
#         {
#           "ELEV": 511,
#           "EW": "W",
#           "LATITUDE": "60.02",
#           "LONGITUDE": "166.33",
#           "Lat": 60.02,
#           "Lon": -166.33,
#           "NAME": "Nunivak Island",
#           "NS": "N",
#           "OBJECTID": 981,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             90.92156862745098,
#             163.01960784313724,
#             207.72549019607845
#           ]
#         },
#         {
#           "ELEV": 190,
#           "EW": "W",
#           "LATITUDE": "61.43",
#           "LONGITUDE": "164.47",
#           "Lat": 61.43,
#           "Lon": -164.47,
#           "NAME": "Ingakslugwat Hills",
#           "NS": "N",
#           "OBJECTID": 982,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             99.92549019607844,
#             169.1686274509804,
#             211.23921568627452
#           ]
#         },
#         {
#           "ELEV": 715,
#           "EW": "W",
#           "LATITUDE": "63.45",
#           "LONGITUDE": "162.12",
#           "Lat": 63.45,
#           "Lon": -162.12,
#           "NAME": "St. Michael",
#           "NS": "N",
#           "OBJECTID": 983,
#           "STATUS": "Anthropology",
#           "SimpleType": "Shield",
#           "TYPE": "Sheild volcano",
#           "color": [
#             85.7764705882353,
#             159.50588235294117,
#             205.71764705882353
#           ]
#         },
#         {
#           "ELEV": 673,
#           "EW": "W",
#           "LATITUDE": "63.60",
#           "LONGITUDE": "170.43",
#           "Lat": 63.6,
#           "Lon": -170.43,
#           "NAME": "Kookooligit Mountains",
#           "NS": "N",
#           "OBJECTID": 984,
#           "STATUS": "Holocene",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             87.06274509803922,
#             160.3843137254902,
#             206.21960784313725
#           ]
#         },
#         {
#           "ELEV": 610,
#           "EW": "W",
#           "LATITUDE": "65.60",
#           "LONGITUDE": "163.92",
#           "Lat": 65.6,
#           "Lon": -163.92,
#           "NAME": "Imuruk Lake",
#           "NS": "N",
#           "OBJECTID": 985,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Shield",
#           "TYPE": "Sheild volcano",
#           "color": [
#             88.34901960784313,
#             161.26274509803923,
#             206.721568627451
#           ]
#         },
#         {
#           "ELEV": 830,
#           "EW": "W",
#           "LATITUDE": "64.07",
#           "LONGITUDE": "148.42",
#           "Lat": 64.07,
#           "Lon": -148.42,
#           "NAME": "Buzzard Creek",
#           "NS": "N",
#           "OBJECTID": 986,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Cinder",
#           "TYPE": "Tuff cone",
#           "color": [
#             83.20392156862745,
#             157.74901960784314,
#             204.71372549019608
#           ]
#         },
#         {
#           "ELEV": 4949,
#           "EW": "W",
#           "LATITUDE": "62.22",
#           "LONGITUDE": "144.13",
#           "Lat": 62.22,
#           "Lon": -144.13,
#           "NAME": "Sanford",
#           "NS": "N",
#           "OBJECTID": 987,
#           "STATUS": "Holocene?",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             8.0,
#             68.70588235294117,
#             137.7450980392157
#           ]
#         },
#         {
#           "ELEV": 4317,
#           "EW": "W",
#           "LATITUDE": "62.00",
#           "LONGITUDE": "144.02",
#           "Lat": 62.0,
#           "Lon": -144.02,
#           "NAME": "Wrangell",
#           "NS": "N",
#           "OBJECTID": 988,
#           "STATUS": "Historical",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             8.88235294117647,
#             82.12941176470588,
#             156.8823529411765
#           ]
#         },
#         {
#           "ELEV": 2755,
#           "EW": "W",
#           "LATITUDE": "62.13",
#           "LONGITUDE": "143.08",
#           "Lat": 62.13,
#           "Lon": -143.08,
#           "NAME": "Gordon",
#           "NS": "N",
#           "OBJECTID": 989,
#           "STATUS": "Holocene?",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             36.364705882352936,
#             116.36470588235294,
#             182.73333333333335
#           ]
#         },
#         {
#           "ELEV": 5005,
#           "EW": "W",
#           "LATITUDE": "61.38",
#           "LONGITUDE": "141.75",
#           "Lat": 61.38,
#           "Lon": -141.75,
#           "NAME": "Churchill",
#           "NS": "N",
#           "OBJECTID": 990,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             8.0,
#             67.6705882352941,
#             136.2078431372549
#           ]
#         },
#         {
#           "ELEV": 970,
#           "EW": "W",
#           "LATITUDE": "57.05",
#           "LONGITUDE": "135.75",
#           "Lat": 57.05,
#           "Lon": -135.75,
#           "NAME": "Edgecumbe",
#           "NS": "N",
#           "OBJECTID": 991,
#           "STATUS": "Radiocarbon",
#           "SimpleType": "Composite",
#           "TYPE": "Stratovolcano",
#           "color": [
#             78.05882352941177,
#             154.23529411764704,
#             202.7058823529412
#           ]
#         },
#         {
#           "ELEV": 15,
#           "EW": "W",
#           "LATITUDE": "56.50",
#           "LONGITUDE": "133.10",
#           "Lat": 56.5,
#           "Lon": -133.1,
#           "NAME": "Duncan Canal",
#           "NS": "N",
#           "OBJECTID": 992,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             105.07058823529412,
#             172.68235294117648,
#             213.24705882352941
#           ]
#         },
#         {
#           "ELEV": 50,
#           "EW": "W",
#           "LATITUDE": "55.25",
#           "LONGITUDE": "133.30",
#           "Lat": 55.25,
#           "Lon": -133.3,
#           "NAME": "Tlevak Strait-Suemez Is.",
#           "NS": "N",
#           "OBJECTID": 993,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             103.7843137254902,
#             171.80392156862746,
#             212.7450980392157
#           ]
#         },
#         {
#           "ELEV": 500,
#           "EW": "W",
#           "LATITUDE": "55.32",
#           "LONGITUDE": "131.05",
#           "Lat": 55.32,
#           "Lon": -131.05,
#           "NAME": "Behm Canal-Rudyerd Bay",
#           "NS": "N",
#           "OBJECTID": 994,
#           "STATUS": "Holocene?",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             92.2078431372549,
#             163.89803921568628,
#             208.22745098039215
#           ]
#         },
#         {
#           "ELEV": 1239,
#           "EW": "W",
#           "LATITUDE": "62.93",
#           "LONGITUDE": "137.38",
#           "Lat": 62.93,
#           "Lon": -137.38,
#           "NAME": "Fort Selkirk",
#           "NS": "N",
#           "OBJECTID": 995,
#           "STATUS": "Holocene?",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             71.62745098039215,
#             149.84313725490193,
#             200.19607843137257
#           ]
#         },
#         {
#           "ELEV": 2217,
#           "EW": "W",
#           "LATITUDE": "60.42",
#           "LONGITUDE": "135.42",
#           "Lat": 60.42,
#           "Lon": -135.42,
#           "NAME": "Alligator Lake",
#           "NS": "N",
#           "OBJECTID": 996,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             48.78823529411765,
#             128.78823529411764,
#             189.13333333333335
#           ]
#         },
#         {
#           "ELEV": 1880,
#           "EW": "W",
#           "LATITUDE": "59.68",
#           "LONGITUDE": "133.32",
#           "Lat": 59.68,
#           "Lon": -133.32,
#           "NAME": "Atlin Volc Field",
#           "NS": "N",
#           "OBJECTID": 997,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Cinder cone",
#           "color": [
#             56.03529411764706,
#             136.03529411764706,
#             192.86666666666667
#           ]
#         },
#         {
#           "ELEV": 2123,
#           "EW": "W",
#           "LATITUDE": "59.37",
#           "LONGITUDE": "130.58",
#           "Lat": 59.37,
#           "Lon": -130.58,
#           "NAME": "Tuya Volc Field",
#           "NS": "N",
#           "OBJECTID": 998,
#           "STATUS": "Holocene",
#           "SimpleType": "Cinder",
#           "TYPE": "Volcanic field",
#           "color": [
#             50.85882352941177,
#             130.85882352941175,
#             190.2
#           ]
#         },
#         {
#           "ELEV": 2012,
#           "EW": "W",
#           "LATITUDE": "58.60",
#           "LONGITUDE": "131.97",
#           "Lat": 58.6,
#           "Lon": -131.97,
#           "NAME": "Heart Peaks",
#           "NS": "N",
#           "OBJECTID": 999,
#           "STATUS": "Holocene?",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             52.92941176470589,
#             132.9294117647059,
#             191.26666666666665
#           ]
#         },
#         {
#           "ELEV": 2190,
#           "EW": "W",
#           "LATITUDE": "58.42",
#           "LONGITUDE": "131.35",
#           "Lat": 58.42,
#           "Lon": -131.35,
#           "NAME": "Level Mountain",
#           "NS": "N",
#           "OBJECTID": 1000,
#           "STATUS": "Holocene?",
#           "SimpleType": "Shield",
#           "TYPE": "Shield volcano",
#           "color": [
#             48.78823529411765,
#             128.78823529411764,
#             189.13333333333335
#           ]
#         }
#       ],
#       "getFillColor": "@@=[color[0], color[1], color[2]]",
#       "getPosition": "@@=[Lon, Lat]",
#       "getRadius": 1,
#       "id": "789778fa-d7db-4418-85aa-5145d5ce7985",
#       "pickable": true,
#       "radiusMaxPixels": 500,
#       "radiusMinPixels": 5,
#       "radiusScale": 1
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/positron-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %% [markdown]
# # How to integrate the pydeck map into a Streamlit app

# %% [markdown]
# <img src="streamlit.png" width="300"/>

# %%
# %%writefile pydeck_streamlit_app.py
import pydeck as pdk
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import streamlit as st

# Page config
st.set_page_config(
    layout="wide",
    initial_sidebar_state="expanded"
)

# Write title
st.title('Volcano Sample Around the World')

# Import data
@st.cache_data
def load_data():
    volcanos = gpd.read_file('https://services.arcgis.com/BG6nSlhZSAWtExvp/arcgis/rest/services/World_Volcanoes/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson')
    volcanos['color'] = volcanos.ELEV.apply(lambda x: [(i * 255) for i in plt.cm.Blues((x-volcanos.ELEV.min()) / (volcanos.ELEV.max() - volcanos.ELEV.min()))[0:3]])
    return volcanos
volcanos = load_data()

# Type selector
sel_type = st.multiselect('Simple Type', volcanos.SimpleType.unique(), default=volcanos.SimpleType.unique())

# View State
view_state = pdk.ViewState(
                longitude=volcanos.Lon.mean(),
                latitude=volcanos.Lat.mean(),
                zoom=1,
                min_zoom=1,
                max_zoom=15
            )

# Points Layer
layer_pts = pdk.Layer(
    type="ScatterplotLayer",
    data=volcanos[volcanos.SimpleType.isin(sel_type)],
    get_fill_color='[color[0], color[1], color[2]]',
    get_radius=1,
    pickable=True,
    radius_scale=1,
    radius_min_pixels=5,
    radius_max_pixels=500,
    get_position='[Lon, Lat]'
    )

# Pydeck object
pdk_map = pdk.Deck(
            map_provider='carto',
            map_style='light',
            initial_view_state=view_state,
            layers=[layer_pts]
            )

# Display pydeck map
st.pydeck_chart(pdk_map)
# Out:
# Overwriting pydeck_streamlit_app.py
